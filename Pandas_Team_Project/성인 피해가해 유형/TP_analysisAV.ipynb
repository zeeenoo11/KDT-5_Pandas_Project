# %%
# Preparance
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import matplotlib.font_manager as fm # 폰트 관련

# 한글 font 설정
font_path =r'C:\Windows\Fonts\gulim.ttc'
#matplotlib 패키지에 한글폰트 설정
myfont = fm.FontProperties(fname= font_path).get_name()
mpl.rc('font', family = myfont)

# %%
# 1.   성인 A
# 1.1. 피해 V

fileSV = '사이버폭력_피해_경험_20240123112345.csv'
DFSV = pd.read_csv(fileSV, header=[1], index_col=[0,1])
DFSV
# Out:
#                           피해 경험률  사이버 언어폭력  사이버 명예훼손  사이버 스토킹  사이버 성폭력  \
# 특성별(1)      특성별(2)
# 전체          소계               8.5       5.2       2.6      3.3      2.2
# 성별          남성               9.5       6.7       2.9      3.3      2.4
#             여성               7.5       3.6       2.3      3.4      1.9
# 연령별         19~29세          18.8      12.8       5.9      6.2      4.1
#             30~39세          11.6       7.4       3.3      4.5      2.5
#             40~49세           6.4       3.3       1.7      2.9      1.9
#             50~59세           4.0       1.9       1.5      2.0      1.3
#             60~69세           3.3       1.6       1.1      1.5      1.4
# 학력별         초졸이하             3.4       0.0       0.0      2.3      1.1
#             중졸               3.5       2.0       0.9      0.3      1.5
#             고졸               6.9       4.0       2.2      2.7      2.0
#             대졸이상            10.5       6.6       3.2      4.1      2.4
# 직업별         전문관리            11.5       4.7       2.7      5.8      2.5
#             사무              12.4       8.1       3.8      5.6      2.9
#             서비스판매            7.1       4.5       2.6      2.7      2.2
#             농어업              2.8       2.1       0.0      1.4      0.7
#             기능노무             5.1       3.1       1.3      1.6      1.2
#             학생              16.4      11.8       4.6      3.5      2.9
#             주부               5.6       2.3       1.5      2.3      1.8
#             무직/기타            8.6       4.9       2.5      3.0      2.1
# 혼인상태별       미혼              16.0      10.8       4.8      5.3      3.1
#             기혼               5.7       3.1       1.7      2.6      1.8
#             사별/이혼/기타         4.7       2.0       1.9      2.4      1.8
# 가구주여부별      가구주              7.8       4.8       2.2      2.9      2.2
#             가구원              9.4       5.6       3.1      3.9      2.2
# 월평균 가구소득별   100만원 미만         8.8       3.4       2.7      2.4      2.7
#             100~200만원 미만     5.9       4.0       1.4      2.2      1.9
#             200~300만원 미만     8.2       5.3       2.5      2.5      1.8
#             300~400만원 미만     7.4       4.6       2.2      2.7      2.1
#             400~500만원 미만     9.4       6.1       3.4      4.2      2.8
#             500~600만원 미만    10.0       5.9       3.4      4.4      2.6
#             600~700만원 미만     8.4       4.7       1.2      2.4      1.1
#             700만원 이상         8.2       4.8       2.2      4.2      1.8
# 동거 가구원수별    1인               9.6       5.8       3.0      3.3      2.1
#             2인               6.0       3.8       1.9      2.8      1.8
#             3인              10.4       5.8       3.1      3.9      2.5
#             4인 이상            8.6       5.5       2.5      3.2      2.2
# 거주지역별       대도시             10.5       6.2       3.9      4.3      3.2
#             중소도시             7.9       5.1       1.7      2.9      1.6
#             읍면지역             4.7       2.6       1.2      1.8      0.9
# 권역별         수도권             10.3       6.6       3.2      4.7      2.8
#             충청권              5.8       3.3       1.7      1.2      0.9
#             호남권              7.5       4.8       2.4      2.3      1.5
#             동북권              6.4       3.2       2.3      2.3      1.9
#             동남권              6.5       3.5       1.6      1.7      1.5
# 인터넷 이용시간별   1시간 미만           3.5       1.2       1.2      1.8      1.6
#             1~2시간 미만         7.4       4.1       2.8      4.1      2.1
#             2~3시간 미만         8.0       5.4       2.4      3.4      2.1
#             3~5시간 미만        10.9       7.1       2.4      3.2      3.0
#             5시간 이상          15.0       9.7       4.5      3.9      2.4
# 사이버폭력 예방교육별 경험 있음           16.7      11.5       4.6      7.8      4.7
#             경험 없음            7.5       4.4       2.4      2.8      1.9
#
#                           신상정보 유출  사이버 따돌림  사이버 갈취  사이버 강요
# 특성별(1)      특성별(2)
# 전체          소계                1.2      1.5     1.0     1.0
# 성별          남성                1.3      1.6     1.1     1.1
#             여성                1.2      1.3     1.0     0.9
# 연령별         19~29세            2.2      3.0     1.7     2.2
#             30~39세            1.7      1.8     1.5     1.0
#             40~49세            0.9      0.8     1.0     0.6
#             50~59세            0.8      1.1     0.6     0.9
#             60~69세            0.7      0.8     0.6     0.5
# 학력별         초졸이하              0.0      2.1     1.1     0.0
#             중졸                0.6      0.9     0.0     0.3
#             고졸                1.0      1.2     0.8     0.9
#             대졸이상              1.5      1.7     1.3     1.2
# 직업별         전문관리              1.1      1.7     1.4     0.6
#             사무                2.4      2.7     1.9     2.2
#             서비스판매             1.0      1.2     1.0     1.1
#             농어업               0.0      0.0     0.0     0.0
#             기능노무              0.5      0.3     0.3     0.1
#             학생                1.2      2.7     1.0     1.2
#             주부                0.9      1.0     0.8     0.4
#             무직/기타             1.3      0.7     0.5     0.3
# 혼인상태별       미혼                1.6      2.3     1.5     1.6
#             기혼                1.0      1.1     0.9     0.8
#             사별/이혼/기타          1.0      0.8     0.7     0.8
# 가구주여부별      가구주               1.0      1.4     1.1     0.9
#             가구원               1.5      1.6     1.0     1.1
# 월평균 가구소득별   100만원 미만          0.0      1.1     0.7     0.4
#             100~200만원 미만      1.1      0.8     0.5     0.5
#             200~300만원 미만      0.7      0.6     0.5     0.4
#             300~400만원 미만      0.8      1.0     1.0     0.8
#             400~500만원 미만      2.0      2.3     1.7     1.9
#             500~600만원 미만      2.1      2.3     1.5     1.7
#             600~700만원 미만      0.5      1.5     0.2     0.2
#             700만원 이상          0.9      1.2     1.0     0.6
# 동거 가구원수별    1인                0.9      1.3     1.2     0.9
#             2인                1.1      1.5     1.0     1.1
#             3인                1.2      1.5     1.2     0.9
#             4인 이상             1.5      1.5     0.9     1.2
# 거주지역별       대도시               2.2      2.4     1.7     1.9
#             중소도시              0.5      0.9     0.8     0.4
#             읍면지역              0.3      0.2     0.1     0.1
# 권역별         수도권               1.9      2.3     1.8     1.8
#             충청권               0.5      0.4     0.1     0.1
#             호남권               0.6      0.4     0.4     0.4
#             동북권               0.4      0.5     0.4     0.2
#             동남권               0.4      0.7     0.0     0.1
# 인터넷 이용시간별   1시간 미만            0.7      0.8     0.9     0.6
#             1~2시간 미만          1.9      2.6     1.7     2.0
#             2~3시간 미만          0.9      0.9     0.6     0.4
#             3~5시간 미만          0.9      1.0     0.6     0.7
#             5시간 이상            1.3      1.5     1.1     0.9
# 사이버폭력 예방교육별 경험 있음             1.7      2.4     2.2     1.9
#             경험 없음             1.2      1.3     0.9     0.9

# %%
# 전체 응답자 중 피해 경험률은 37.5%, 이 중 언어폭력이 가장 높고 명예 훼손, 스토킹 순으로 나타납니다. 


# 전체 비율 비교
dfL0 = DFSV.xs(DFSV.index[0][0], level=0)  # DF 추출 : '전체'


# ------------- 전체 크기 -----------------
plt.figure(figsize=(5,5))


# -------------- 그래프 1 -----------------
WITDH = 5  # 막대 너비

xlabelList = [0,10,20,30,40,50,60,70,80]
x2labelList = list(map(lambda x:x+WITDH,xlabelList))

# ----------- 바 그래프 함수 --------------
plt.bar(
    xlabelList,dfL0.iloc(0)[0], width=WITDH, 
    color=['#F6546A','#045FB4', '#6497b1', '#b3cde0', '#81BEF7', '#A9D0F5', '#CEE3F6', '#81BEF7', '#CEE3F6', "#b3cde0"]
    )

plt.xticks(ticks=xlabelList, labels=dfL0.columns, rotation=315)

# ------------ 제목 설정 ------------------
plt.title("[ 사이버 폭력 피해 경험 ]")

# ------------ 축 다듬기 ------------------
plt.ylabel('%', loc='top', fontsize='large')

# ------------ 범례 설정 ------------------
# plt.legend(['남한', '북한'])

# ------------ 눈금 설정 ------------------
# maxValue = max([max(waterDF[i]) for i in waterDF.columns])

# plt.xticks(ticks=[i for i in range(0, 30, 5)])
# plt.yticks(ticks=[i for i in range(0, maxValue, maxValue//10)])

# ------------ 격자 설정 ------------------
# plt.grid(True, lw =0.5, ls ='-.', c='.9')
# Out:
# Text(0, 1, '%')

# %%
DFSV.head()
# Out:
#                피해 경험률  사이버 언어폭력  사이버 명예훼손  사이버 스토킹  사이버 성폭력  신상정보 유출  사이버 따돌림  \
# 특성별(1) 특성별(2)
# 전체     소계         8.5       5.2       2.6      3.3      2.2      1.2      1.5
# 성별     남성         9.5       6.7       2.9      3.3      2.4      1.3      1.6
#        여성         7.5       3.6       2.3      3.4      1.9      1.2      1.3
# 연령별    19~29세    18.8      12.8       5.9      6.2      4.1      2.2      3.0
#        30~39세    11.6       7.4       3.3      4.5      2.5      1.7      1.8
#
#                사이버 갈취  사이버 강요
# 특성별(1) 특성별(2)
# 전체     소계         1.0     1.0
# 성별     남성         1.1     1.1
#        여성         1.0     0.9
# 연령별    19~29세     1.7     2.2
#        30~39세     1.5     1.0

# %%
# 성별을 기준으로 보면 남학생의 피해 경험률은 42.1%, 여학생의 피해 경험률은 32.5% 이며 항목별 순서는 전체 비율과 동일합니다.


# 전체 비율 비교
dfL1 = DFSV.xs(DFSV.index[1][0], level=0)  # DF 추출 : '성별'

# ------------- 전체 크기 -----------------
plt.figure(figsize=(10,5))


# -------------- 그래프 1 -----------------
WITDH = 5  # 막대 너비

xlabelList = [0,15,30,45,60,75,90,105,120]
x2labelList = list(map(lambda x:x+WITDH,xlabelList))

# ----------- 바 그래프 함수 --------------
plt.bar(
    xlabelList,dfL1.iloc(0)[0], width=WITDH, 
    color=['#045FB4', '#6497b1', '#b3cde0', '#81BEF7', '#A9D0F5', '#CEE3F6', '#81BEF7', '#CEE3F6', "#b3cde0"]
    )
plt.bar(
    x2labelList,dfL1.iloc(0)[1], width=WITDH, 
    color=[ '#D32F2F','#E57373','#FFCDD2', '#EF9A9A', '#FF8A80','#EF9A9A', '#FFCDD2','#FF8A80', '#EF9A9A']
    )

# ------------ 눈금 설정 ------------------
plt.xticks(ticks=xlabelList, labels=dfL1.columns, rotation=315)

# ------------ 제목 설정 ------------------
plt.title("[ 사이버 폭력 피해 경험 ]")

# ------------ 축 다듬기 ------------------
plt.ylabel('%', loc='top', fontsize='large')

# ------------ 범례 설정 ------------------
plt.legend(['남성', '여성'])

# ------------ 눈금 설정 ------------------
# maxValue = max([max(waterDF[i]) for i in waterDF.columns])

# plt.xticks(ticks=[i for i in range(0, 30, 5)])
# plt.yticks(ticks=[i for i in range(0, maxValue, maxValue//10)])

# ------------ 격자 설정 ------------------
# plt.grid(True, lw =0.5, ls ='-.', c='.9')

# %% [markdown]
# <hr>

# %%
DFSV
# Out:
#                           피해 경험률  사이버 언어폭력  사이버 명예훼손  사이버 스토킹  사이버 성폭력  \
# 특성별(1)      특성별(2)
# 전체          소계               8.5       5.2       2.6      3.3      2.2
# 성별          남성               9.5       6.7       2.9      3.3      2.4
#             여성               7.5       3.6       2.3      3.4      1.9
# 연령별         19~29세          18.8      12.8       5.9      6.2      4.1
#             30~39세          11.6       7.4       3.3      4.5      2.5
#             40~49세           6.4       3.3       1.7      2.9      1.9
#             50~59세           4.0       1.9       1.5      2.0      1.3
#             60~69세           3.3       1.6       1.1      1.5      1.4
# 학력별         초졸이하             3.4       0.0       0.0      2.3      1.1
#             중졸               3.5       2.0       0.9      0.3      1.5
#             고졸               6.9       4.0       2.2      2.7      2.0
#             대졸이상            10.5       6.6       3.2      4.1      2.4
# 직업별         전문관리            11.5       4.7       2.7      5.8      2.5
#             사무              12.4       8.1       3.8      5.6      2.9
#             서비스판매            7.1       4.5       2.6      2.7      2.2
#             농어업              2.8       2.1       0.0      1.4      0.7
#             기능노무             5.1       3.1       1.3      1.6      1.2
#             학생              16.4      11.8       4.6      3.5      2.9
#             주부               5.6       2.3       1.5      2.3      1.8
#             무직/기타            8.6       4.9       2.5      3.0      2.1
# 혼인상태별       미혼              16.0      10.8       4.8      5.3      3.1
#             기혼               5.7       3.1       1.7      2.6      1.8
#             사별/이혼/기타         4.7       2.0       1.9      2.4      1.8
# 가구주여부별      가구주              7.8       4.8       2.2      2.9      2.2
#             가구원              9.4       5.6       3.1      3.9      2.2
# 월평균 가구소득별   100만원 미만         8.8       3.4       2.7      2.4      2.7
#             100~200만원 미만     5.9       4.0       1.4      2.2      1.9
#             200~300만원 미만     8.2       5.3       2.5      2.5      1.8
#             300~400만원 미만     7.4       4.6       2.2      2.7      2.1
#             400~500만원 미만     9.4       6.1       3.4      4.2      2.8
#             500~600만원 미만    10.0       5.9       3.4      4.4      2.6
#             600~700만원 미만     8.4       4.7       1.2      2.4      1.1
#             700만원 이상         8.2       4.8       2.2      4.2      1.8
# 동거 가구원수별    1인               9.6       5.8       3.0      3.3      2.1
#             2인               6.0       3.8       1.9      2.8      1.8
#             3인              10.4       5.8       3.1      3.9      2.5
#             4인 이상            8.6       5.5       2.5      3.2      2.2
# 거주지역별       대도시             10.5       6.2       3.9      4.3      3.2
#             중소도시             7.9       5.1       1.7      2.9      1.6
#             읍면지역             4.7       2.6       1.2      1.8      0.9
# 권역별         수도권             10.3       6.6       3.2      4.7      2.8
#             충청권              5.8       3.3       1.7      1.2      0.9
#             호남권              7.5       4.8       2.4      2.3      1.5
#             동북권              6.4       3.2       2.3      2.3      1.9
#             동남권              6.5       3.5       1.6      1.7      1.5
# 인터넷 이용시간별   1시간 미만           3.5       1.2       1.2      1.8      1.6
#             1~2시간 미만         7.4       4.1       2.8      4.1      2.1
#             2~3시간 미만         8.0       5.4       2.4      3.4      2.1
#             3~5시간 미만        10.9       7.1       2.4      3.2      3.0
#             5시간 이상          15.0       9.7       4.5      3.9      2.4
# 사이버폭력 예방교육별 경험 있음           16.7      11.5       4.6      7.8      4.7
#             경험 없음            7.5       4.4       2.4      2.8      1.9
#
#                           신상정보 유출  사이버 따돌림  사이버 갈취  사이버 강요
# 특성별(1)      특성별(2)
# 전체          소계                1.2      1.5     1.0     1.0
# 성별          남성                1.3      1.6     1.1     1.1
#             여성                1.2      1.3     1.0     0.9
# 연령별         19~29세            2.2      3.0     1.7     2.2
#             30~39세            1.7      1.8     1.5     1.0
#             40~49세            0.9      0.8     1.0     0.6
#             50~59세            0.8      1.1     0.6     0.9
#             60~69세            0.7      0.8     0.6     0.5
# 학력별         초졸이하              0.0      2.1     1.1     0.0
#             중졸                0.6      0.9     0.0     0.3
#             고졸                1.0      1.2     0.8     0.9
#             대졸이상              1.5      1.7     1.3     1.2
# 직업별         전문관리              1.1      1.7     1.4     0.6
#             사무                2.4      2.7     1.9     2.2
#             서비스판매             1.0      1.2     1.0     1.1
#             농어업               0.0      0.0     0.0     0.0
#             기능노무              0.5      0.3     0.3     0.1
#             학생                1.2      2.7     1.0     1.2
#             주부                0.9      1.0     0.8     0.4
#             무직/기타             1.3      0.7     0.5     0.3
# 혼인상태별       미혼                1.6      2.3     1.5     1.6
#             기혼                1.0      1.1     0.9     0.8
#             사별/이혼/기타          1.0      0.8     0.7     0.8
# 가구주여부별      가구주               1.0      1.4     1.1     0.9
#             가구원               1.5      1.6     1.0     1.1
# 월평균 가구소득별   100만원 미만          0.0      1.1     0.7     0.4
#             100~200만원 미만      1.1      0.8     0.5     0.5
#             200~300만원 미만      0.7      0.6     0.5     0.4
#             300~400만원 미만      0.8      1.0     1.0     0.8
#             400~500만원 미만      2.0      2.3     1.7     1.9
#             500~600만원 미만      2.1      2.3     1.5     1.7
#             600~700만원 미만      0.5      1.5     0.2     0.2
#             700만원 이상          0.9      1.2     1.0     0.6
# 동거 가구원수별    1인                0.9      1.3     1.2     0.9
#             2인                1.1      1.5     1.0     1.1
#             3인                1.2      1.5     1.2     0.9
#             4인 이상             1.5      1.5     0.9     1.2
# 거주지역별       대도시               2.2      2.4     1.7     1.9
#             중소도시              0.5      0.9     0.8     0.4
#             읍면지역              0.3      0.2     0.1     0.1
# 권역별         수도권               1.9      2.3     1.8     1.8
#             충청권               0.5      0.4     0.1     0.1
#             호남권               0.6      0.4     0.4     0.4
#             동북권               0.4      0.5     0.4     0.2
#             동남권               0.4      0.7     0.0     0.1
# 인터넷 이용시간별   1시간 미만            0.7      0.8     0.9     0.6
#             1~2시간 미만          1.9      2.6     1.7     2.0
#             2~3시간 미만          0.9      0.9     0.6     0.4
#             3~5시간 미만          0.9      1.0     0.6     0.7
#             5시간 이상            1.3      1.5     1.1     0.9
# 사이버폭력 예방교육별 경험 있음             1.7      2.4     2.2     1.9
#             경험 없음             1.2      1.3     0.9     0.9

# %%
pd.DataFrame(DFSV['피해 경험률'].reset_index(level=1, drop=True))[1:-1]
# Out:
#              피해 경험률
# 특성별(1)
# 성별              9.5
# 성별              7.5
# 연령별            18.8
# 연령별            11.6
# 연령별             6.4
# 연령별             4.0
# 연령별             3.3
# 학력별             3.4
# 학력별             3.5
# 학력별             6.9
# 학력별            10.5
# 직업별            11.5
# 직업별            12.4
# 직업별             7.1
# 직업별             2.8
# 직업별             5.1
# 직업별            16.4
# 직업별             5.6
# 직업별             8.6
# 혼인상태별          16.0
# 혼인상태별           5.7
# 혼인상태별           4.7
# 가구주여부별          7.8
# 가구주여부별          9.4
# 월평균 가구소득별       8.8
# 월평균 가구소득별       5.9
# 월평균 가구소득별       8.2
# 월평균 가구소득별       7.4
# 월평균 가구소득별       9.4
# 월평균 가구소득별      10.0
# 월평균 가구소득별       8.4
# 월평균 가구소득별       8.2
# 동거 가구원수별        9.6
# 동거 가구원수별        6.0
# 동거 가구원수별       10.4
# 동거 가구원수별        8.6
# 거주지역별          10.5
# 거주지역별           7.9
# 거주지역별           4.7
# 권역별            10.3
# 권역별             5.8
# 권역별             7.5
# 권역별             6.4
# 권역별             6.5
# 인터넷 이용시간별       3.5
# 인터넷 이용시간별       7.4
# 인터넷 이용시간별       8.0
# 인터넷 이용시간별      10.9
# 인터넷 이용시간별      15.0
# 사이버폭력 예방교육별    16.7

# %%
# 각 특성별 피해 경험 비율

# ------------- 전체 크기 -----------------
plt.figure(figsize=(10,5))
# xlabelList=[0, 10, 20, 30, 40, 50, 60,70]

pd.DataFrame(DFSV['피해 경험률'].reset_index(level=1, drop=True))[1:-1].plot()

# ------------ 제목 설정 ------------------
plt.title("[ 전체 사이버 폭력 피해 경험 비율 ]")

# ------------ 축 다듬기 ------------------
plt.ylabel('%', loc='top', fontsize='medium', rotation=180)
plt.xlabel('특성 대분류', loc='center')

# ------------ 범례 설정 ------------------
plt.legend([])

# ------------ 눈금 설정    ------------------
plt.xticks(rotation=330)
plt.ylim(0,70)

# ------------ 격자 설정 ------------------
plt.annotate('19~29세(18.8%)', (0,20))
plt.annotate('학생 (16.4%)', (13,20))
plt.annotate('미혼 (16.0%)', (16,24))
plt.annotate('인터넷 이용시간\n  5시간 이상 (15.0%)', (35,20))

# ------------ 격자 설정 ------------------
plt.grid(True, lw =0.5, ls ='-.', c='.9')

# %%
# 야전진우 바보똥개
