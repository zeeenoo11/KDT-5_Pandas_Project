# %%
# Preparance
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import matplotlib.font_manager as fm # 폰트 관련

# 한글 font 설정
font_path =r'C:\Windows\Fonts\gulim.ttc'
#matplotlib 패키지에 한글폰트 설정
myfont = fm.FontProperties(fname= font_path).get_name()
mpl.rc('font', family = myfont)

# %%
# 1.   학생 S
# 1.1. 피해 V

fileSV = '사이버폭력_피해_경험_20240119170346.csv'
DFSV = pd.read_csv(fileSV, header=[1], index_col=[0,1])
DFSV
# Out:
#                       피해 경험률  사이버 언어폭력  사이버 명예훼손  사이버 스토킹  사이버 성폭력  신상정보 유출  \
# 특성별(1)      특성별(2)
# 전체          소계          37.5      33.3      16.1      7.7      6.1      5.9
# 성별          남학생         42.1      38.0      17.9      7.5      7.2      7.0
#             여학생         32.5      28.4      14.1      8.0      5.0      4.7
# 학령별         초등학교        39.3      34.3      15.8      5.9      5.2      4.3
#             중학교         41.3      37.7      19.9     10.1      7.8      8.7
#             고등학교        31.5      27.8      12.4      7.1      5.3      4.6
# 학교특성별       남학교         39.8      35.8      16.8      7.6      7.8      7.6
#             여학교         28.2      24.3      11.7      9.1      5.2      3.9
#             남녀공학        37.3      33.8      17.0      8.8      6.5      7.0
# 거주지역별       대도시         35.6      31.7      15.6      7.4      5.6      5.6
#             중소도시        39.6      35.2      17.0      8.4      6.7      6.6
#             읍면지역        34.8      31.5      14.2      6.0      5.2      3.9
# 권역별         수도권         38.0      33.9      17.0      7.8      6.0      6.1
#             충청권         37.5      33.8      15.5      8.9      6.9      5.7
#             호남권         35.2      30.7      14.4      7.4      5.7      5.7
#             동북권         35.8      32.2      15.3      6.4      6.5      5.7
#             동남권         38.5      33.9      15.3      7.8      5.8      5.5
# 인터넷 이용 시간별  1시간 미만      20.4      16.9       8.1      3.5      4.6      4.5
#             1~2시간 미만    33.0      27.7      13.4      5.1      4.2      4.5
#             2~3시간 미만    36.0      31.9      15.3      7.0      5.5      5.0
#             3~5시간 미만    40.7      37.0      16.8      8.5      6.2      6.0
#             5시간 이상      43.3      39.3      20.2     10.5      8.4      8.0
# 가정형편별       상위          36.1      30.8      18.6      9.3      7.9      7.0
#             중위          37.7      33.7      15.9      7.4      5.8      5.7
#             하위          36.7      31.6      13.8     10.2      9.2      6.8
# 학업성적별       상위권         37.1      32.5      17.8      7.8      6.5      6.3
#             중위권         37.7      33.7      15.7      7.4      5.9      5.6
#             하위권         36.2      32.0      15.8     10.1      7.1      6.9
# 사이버폭력 예방교육별 경험 있음       38.0      33.9      16.2      7.6      5.9      5.8
#             경험 없음       33.4      29.4      15.2      9.0      7.9      6.4
#
#                       사이버 따돌림  사이버 갈취  사이버 강요
# 특성별(1)      특성별(2)
# 전체          소계            5.0     4.4     4.0
# 성별          남학생           6.0     6.4     4.7
#             여학생           4.0     2.3     3.2
# 학령별         초등학교          7.1     5.3     4.3
#             중학교           5.0     4.6     4.2
#             고등학교          2.9     3.2     3.4
# 학교특성별       남학교           4.7     5.3     4.5
#             여학교           2.3     1.7     2.0
#             남녀공학          4.1     4.0     4.0
# 거주지역별       대도시           4.5     4.0     3.3
#             중소도시          5.8     5.0     4.7
#             읍면지역          3.6     3.1     2.9
# 권역별         수도권           4.7     4.3     4.0
#             충청권           6.1     5.1     4.7
#             호남권           5.1     4.7     3.1
#             동북권           5.0     4.3     4.2
#             동남권           5.2     4.1     3.6
# 인터넷 이용 시간별  1시간 미만        4.7     3.9     3.1
#             1~2시간 미만      4.9     3.6     3.2
#             2~3시간 미만      4.7     4.2     4.0
#             3~5시간 미만      5.1     4.6     3.7
#             5시간 이상        5.5     5.0     5.0
# 가정형편별       상위            5.6     6.0     4.9
#             중위            4.9     4.1     3.7
#             하위            7.6     5.8     6.9
# 학업성적별       상위권           6.1     4.4     4.1
#             중위권           4.6     4.3     3.7
#             하위권           6.4     5.5     6.0
# 사이버폭력 예방교육별 경험 있음         5.0     4.2     3.8
#             경험 없음         5.4     5.5     5.2

# %%
# 전체 응답자 중 피해 경험률은 37.5%, 이 중 언어폭력이 가장 높고 명예 훼손, 스토킹 순으로 나타납니다. 


# 전체 비율 비교
dfL0 = DFSV.xs(DFSV.index[0][0], level=0)  # DF 추출 : '전체'


# ------------- 전체 크기 -----------------
plt.figure(figsize=(5,5))


# -------------- 그래프 1 -----------------
WITDH = 5  # 막대 너비

xlabelList = [0,10,20,30,40,50,60,70,80]
x2labelList = list(map(lambda x:x+WITDH,xlabelList))

# ----------- 바 그래프 함수 --------------
plt.bar(
    xlabelList,dfL0.iloc(0)[0], width=WITDH, 
    color=['#F6546A','#045FB4', '#6497b1', '#b3cde0', '#81BEF7', '#A9D0F5', '#CEE3F6', '#81BEF7', '#CEE3F6', "#b3cde0"]
    )

plt.xticks(ticks=xlabelList, labels=dfL0.columns, rotation=315)

# ------------ 제목 설정 ------------------
plt.title("[ 사이버 폭력 피해 경험 ]")

# ------------ 축 다듬기 ------------------
plt.ylabel('%', loc='top', fontsize='large')

# ------------ 범례 설정 ------------------
# plt.legend(['남한', '북한'])

# ------------ 눈금 설정 ------------------
# maxValue = max([max(waterDF[i]) for i in waterDF.columns])

# plt.xticks(ticks=[i for i in range(0, 30, 5)])
# plt.yticks(ticks=[i for i in range(0, maxValue, maxValue//10)])

# ------------ 격자 설정 ------------------
# plt.grid(True, lw =0.5, ls ='-.', c='.9')
# Out:
# Text(0, 1, '%')

# %%
DFSV.head()
# Out:
#                피해 경험률  사이버 언어폭력  사이버 명예훼손  사이버 스토킹  사이버 성폭력  신상정보 유출  사이버 따돌림  \
# 특성별(1) 특성별(2)
# 전체     소계        37.5      33.3      16.1      7.7      6.1      5.9      5.0
# 성별     남학생       42.1      38.0      17.9      7.5      7.2      7.0      6.0
#        여학생       32.5      28.4      14.1      8.0      5.0      4.7      4.0
# 학령별    초등학교      39.3      34.3      15.8      5.9      5.2      4.3      7.1
#        중학교       41.3      37.7      19.9     10.1      7.8      8.7      5.0
#
#                사이버 갈취  사이버 강요
# 특성별(1) 특성별(2)
# 전체     소계         4.4     4.0
# 성별     남학생        6.4     4.7
#        여학생        2.3     3.2
# 학령별    초등학교       5.3     4.3
#        중학교        4.6     4.2

# %%
# 성별을 기준으로 보면 남학생의 피해 경험률은 42.1%, 여학생의 피해 경험률은 32.5% 이며 항목별 순서는 전체 비율과 동일합니다.


# 전체 비율 비교
dfL1 = DFSV.xs(DFSV.index[1][0], level=0)  # DF 추출 : '성별'

# ------------- 전체 크기 -----------------
plt.figure(figsize=(10,5))


# -------------- 그래프 1 -----------------
WITDH = 5  # 막대 너비

xlabelList = [0,15,30,45,60,75,90,105,120]
x2labelList = list(map(lambda x:x+WITDH,xlabelList))

# ----------- 바 그래프 함수 --------------
plt.bar(
    xlabelList,dfL1.iloc(0)[0], width=WITDH, 
    color=['#045FB4', '#6497b1', '#b3cde0', '#81BEF7', '#A9D0F5', '#CEE3F6', '#81BEF7', '#CEE3F6', "#b3cde0"]
    )
plt.bar(
    x2labelList,dfL1.iloc(0)[1], width=WITDH, 
    color=[ '#D32F2F','#E57373','#FFCDD2', '#EF9A9A', '#FF8A80','#EF9A9A', '#FFCDD2','#FF8A80', '#EF9A9A']
    )

# ------------ 눈금 설정 ------------------
plt.xticks(ticks=xlabelList, labels=dfL1.columns, rotation=315)

# ------------ 제목 설정 ------------------
plt.title("[ 사이버 폭력 피해 경험 ]")

# ------------ 축 다듬기 ------------------
plt.ylabel('%', loc='top', fontsize='large')

# ------------ 범례 설정 ------------------
plt.legend(['남학생', '여학생'])

# ------------ 눈금 설정 ------------------
# maxValue = max([max(waterDF[i]) for i in waterDF.columns])

# plt.xticks(ticks=[i for i in range(0, 30, 5)])
# plt.yticks(ticks=[i for i in range(0, maxValue, maxValue//10)])

# ------------ 격자 설정 ------------------
# plt.grid(True, lw =0.5, ls ='-.', c='.9')

# %% [markdown]
# <hr>

# %%
DFSV
# Out:
#                       피해 경험률  사이버 언어폭력  사이버 명예훼손  사이버 스토킹  사이버 성폭력  신상정보 유출  \
# 특성별(1)      특성별(2)
# 전체          소계          37.5      33.3      16.1      7.7      6.1      5.9
# 성별          남학생         42.1      38.0      17.9      7.5      7.2      7.0
#             여학생         32.5      28.4      14.1      8.0      5.0      4.7
# 학령별         초등학교        39.3      34.3      15.8      5.9      5.2      4.3
#             중학교         41.3      37.7      19.9     10.1      7.8      8.7
#             고등학교        31.5      27.8      12.4      7.1      5.3      4.6
# 학교특성별       남학교         39.8      35.8      16.8      7.6      7.8      7.6
#             여학교         28.2      24.3      11.7      9.1      5.2      3.9
#             남녀공학        37.3      33.8      17.0      8.8      6.5      7.0
# 거주지역별       대도시         35.6      31.7      15.6      7.4      5.6      5.6
#             중소도시        39.6      35.2      17.0      8.4      6.7      6.6
#             읍면지역        34.8      31.5      14.2      6.0      5.2      3.9
# 권역별         수도권         38.0      33.9      17.0      7.8      6.0      6.1
#             충청권         37.5      33.8      15.5      8.9      6.9      5.7
#             호남권         35.2      30.7      14.4      7.4      5.7      5.7
#             동북권         35.8      32.2      15.3      6.4      6.5      5.7
#             동남권         38.5      33.9      15.3      7.8      5.8      5.5
# 인터넷 이용 시간별  1시간 미만      20.4      16.9       8.1      3.5      4.6      4.5
#             1~2시간 미만    33.0      27.7      13.4      5.1      4.2      4.5
#             2~3시간 미만    36.0      31.9      15.3      7.0      5.5      5.0
#             3~5시간 미만    40.7      37.0      16.8      8.5      6.2      6.0
#             5시간 이상      43.3      39.3      20.2     10.5      8.4      8.0
# 가정형편별       상위          36.1      30.8      18.6      9.3      7.9      7.0
#             중위          37.7      33.7      15.9      7.4      5.8      5.7
#             하위          36.7      31.6      13.8     10.2      9.2      6.8
# 학업성적별       상위권         37.1      32.5      17.8      7.8      6.5      6.3
#             중위권         37.7      33.7      15.7      7.4      5.9      5.6
#             하위권         36.2      32.0      15.8     10.1      7.1      6.9
# 사이버폭력 예방교육별 경험 있음       38.0      33.9      16.2      7.6      5.9      5.8
#             경험 없음       33.4      29.4      15.2      9.0      7.9      6.4
#
#                       사이버 따돌림  사이버 갈취  사이버 강요
# 특성별(1)      특성별(2)
# 전체          소계            5.0     4.4     4.0
# 성별          남학생           6.0     6.4     4.7
#             여학생           4.0     2.3     3.2
# 학령별         초등학교          7.1     5.3     4.3
#             중학교           5.0     4.6     4.2
#             고등학교          2.9     3.2     3.4
# 학교특성별       남학교           4.7     5.3     4.5
#             여학교           2.3     1.7     2.0
#             남녀공학          4.1     4.0     4.0
# 거주지역별       대도시           4.5     4.0     3.3
#             중소도시          5.8     5.0     4.7
#             읍면지역          3.6     3.1     2.9
# 권역별         수도권           4.7     4.3     4.0
#             충청권           6.1     5.1     4.7
#             호남권           5.1     4.7     3.1
#             동북권           5.0     4.3     4.2
#             동남권           5.2     4.1     3.6
# 인터넷 이용 시간별  1시간 미만        4.7     3.9     3.1
#             1~2시간 미만      4.9     3.6     3.2
#             2~3시간 미만      4.7     4.2     4.0
#             3~5시간 미만      5.1     4.6     3.7
#             5시간 이상        5.5     5.0     5.0
# 가정형편별       상위            5.6     6.0     4.9
#             중위            4.9     4.1     3.7
#             하위            7.6     5.8     6.9
# 학업성적별       상위권           6.1     4.4     4.1
#             중위권           4.6     4.3     3.7
#             하위권           6.4     5.5     6.0
# 사이버폭력 예방교육별 경험 있음         5.0     4.2     3.8
#             경험 없음         5.4     5.5     5.2

# %%
pd.DataFrame(DFSV['피해 경험률'].reset_index(level=1, drop=True))[1:-1]
# Out:
#              피해 경험률
# 특성별(1)
# 성별             42.1
# 성별             32.5
# 학령별            39.3
# 학령별            41.3
# 학령별            31.5
# 학교특성별          39.8
# 학교특성별          28.2
# 학교특성별          37.3
# 거주지역별          35.6
# 거주지역별          39.6
# 거주지역별          34.8
# 권역별            38.0
# 권역별            37.5
# 권역별            35.2
# 권역별            35.8
# 권역별            38.5
# 인터넷 이용 시간별     20.4
# 인터넷 이용 시간별     33.0
# 인터넷 이용 시간별     36.0
# 인터넷 이용 시간별     40.7
# 인터넷 이용 시간별     43.3
# 가정형편별          36.1
# 가정형편별          37.7
# 가정형편별          36.7
# 학업성적별          37.1
# 학업성적별          37.7
# 학업성적별          36.2
# 사이버폭력 예방교육별    38.0

# %%
# 각 특성별 피해 경험 비율

# ------------- 전체 크기 -----------------
plt.figure(figsize=(10,5))
# xlabelList=[0, 10, 20, 30, 40, 50, 60,70]

pd.DataFrame(DFSV['피해 경험률'].reset_index(level=1, drop=True))[1:-1].plot()

# ------------ 제목 설정 ------------------
plt.title("[ 전체 사이버 폭력 피해 경험 비율 ]")

# ------------ 축 다듬기 ------------------
plt.ylabel('%', loc='top', fontsize='medium', rotation=180)
plt.xlabel('특성 대분류', loc='center')

# ------------ 범례 설정 ------------------
plt.legend([])

# ------------ 눈금 설정    ------------------
plt.xticks(rotation=330)
plt.ylim(0,70)

# ------------ 격자 설정 ------------------
plt.annotate('1시간 미만', (14,16))

# ------------ 격자 설정 ------------------
plt.grid(True, lw =0.5, ls ='-.', c='.9')

# %%
# 야전진우 바보똥개
